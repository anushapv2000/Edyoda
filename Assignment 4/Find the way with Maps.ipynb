# %%
lists=[int(i) for i in input("Enter numbers seperated by ',': ").split(',')]
print("input list:",lists)
l=list(map(lambda x:x*3,lists))
print("triple of list numbers:",l)
# Out:
# Enter numbers seperated by ',': 1,2,3,4,5,6,7
# input list: [1, 2, 3, 4, 5, 6, 7]
# triple of list numbers: [3, 6, 9, 12, 15, 18, 21]
